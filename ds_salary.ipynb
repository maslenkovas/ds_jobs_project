# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import glassdoor_scraper as gs
import pickle5 as pickle

# %%
# check if the driver works
from selenium import webdriver
driver = webdriver.Chrome("/Users/svetlanamaslenkova/Documents/DS_project/chromedriver_mac64/chromedriver")
# Out:
# /Users/svetlanamaslenkova/anaconda3/envs/ds_salary_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
import datetime
from datetime import date

# date when the data was scrapped
d = date(2023, 2, 6)
print(d)
# Out:
# 2023-02-06

# %%
with open('/Users/svetlanamaslenkova/Documents/DS_project/da_jobs_scraped.pkl', 'rb') as handle:
    da_jobs_df = pickle.load(handle)

# add the column with the date of datascrapping
da_jobs_df['date_scrapped'] = d
da_jobs_df.head()
# Out:
#               Job Title                  Salary Estimate  \
# 0          Data Analyst                               -1
# 1          Data Analyst                               -1
# 2  Data Insight Analyst  AED 4K - AED 6K (Employer est.)
# 3          Data Analyst  AED 5K - AED 6K (Employer est.)
# 4          Data Analyst                               -1
#
#                                      Job Description Rating  \
# 0  We are looking for an enthusiastic and experie...    4.1
# 1  Majid Al Futtaim invites you to join us in our...    3.8
# 2  Job description\nWe are looking for someone in...     -1
# 3  Roles & Responsibilities\nPreparing reports th...     -1
# 4  Job Description:\nWe are looking to hire a dat...     -1
#
#                         Company Name Location    job_age                 Size  \
# 0                   haus & haus\n4.1    Dubai        13d  51 to 200 Employees
# 1   Majid al Futtaim Properties\n3.8    Dubai  1 day ago     10000+ Employees
# 2  Kazix Project Management Services    Dubai         3d                   -1
# 3                      Metworld DMCC    Dubai         4d                   -1
# 4                      Lime Concepts    Dubai        18d                   -1
#
#   Founded  Type of ownership                            Industry  \
# 0    2013  Company - Private                         Real Estate
# 1    1930  Company - Private  Department, Clothing & Shoe Stores
# 2      -1                 -1                                  -1
# 3      -1                 -1                                  -1
# 4      -1                 -1                                  -1
#
#                Sector                   Revenue  Competitors date_scrapped
# 0         Real Estate  Unknown / Non-Applicable           -1    2023-02-06
# 1  Retail & Wholesale   $5 to $10 billion (USD)           -1    2023-02-06
# 2                  -1                        -1           -1    2023-02-06
# 3                  -1                        -1           -1    2023-02-06
# 4                  -1                        -1           -1    2023-02-06

# %%
with open('/Users/svetlanamaslenkova/Documents/DS_project/ds_jobs_scraped.pkl', 'rb') as handle:
    ds_jobs_df = pickle.load(handle)
# add the column with the date of datascrapping
ds_jobs_df['date_scrapped'] = d
ds_jobs_df.head()
# Out:
#                                            Job Title Salary Estimate  \
# 0                 JUNIOR DATA SCIENTIST - Dubai, UAE              -1
# 1                        DATA SCIENTIST - Dubai, UAE              -1
# 2  Data Analyst/ Data Scientist (UAE Nationals ONLY)              -1
# 3             Data Analyst / Data Scientist (Remote)              -1
# 4                 SENIOR DATA SCIENTIST - Dubai, UAE              -1
#
#                                      Job Description Rating  \
# 0  Location: Dubai, UAE (We provide visa sponsors...     -1
# 1  Location: Dubai, UAE (We provide visa sponsors...    5.0
# 2  Develop a well-designed system of institutiona...     -1
# 3  nybl is looking for our next generation of dat...     -1
# 4  Employment type: Full-time & Permanent\nReport...    5.0
#
#                        Company Name Location job_age               Size  \
# 0  Cobblestone Energy, Dubai - UAE.  Sharjah    30d+                 -1
# 1                  Cobblestone\n5.0    Dubai     24h  1 to 50 Employees
# 2        جامعة حمدان بن محمد الذكية    Dubai      7d                 -1
# 3                              nybl    Dubai    30d+                 -1
# 4                  Cobblestone\n5.0    Dubai     10d  1 to 50 Employees
#
#   Founded  Type of ownership Industry Sector                   Revenue  \
# 0      -1                 -1       -1     -1                        -1
# 1      -1  Company - Private       -1     -1  Unknown / Non-Applicable
# 2      -1                 -1       -1     -1                        -1
# 3      -1                 -1       -1     -1                        -1
# 4      -1  Company - Private       -1     -1  Unknown / Non-Applicable
#
#    Competitors date_scrapped
# 0           -1    2023-02-06
# 1           -1    2023-02-06
# 2           -1    2023-02-06
# 3           -1    2023-02-06
# 4           -1    2023-02-06
